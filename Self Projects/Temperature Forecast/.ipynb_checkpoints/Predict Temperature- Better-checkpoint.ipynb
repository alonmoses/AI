# %%
import torch
import torch.nn as nn

import pandas as pd
import numpy as np

import time
import matplotlib.pyplot as plt

import SelfAI

# %% [markdown]
# ### Reading the Data

# %%
df = pd.read_csv('Weather Sats.csv')
df.head()
# Out:
#          Date   Hour Temperature Wet Temperature Dew point Temperature  \
# 0  01/04/2010   2:00        13.6            10.8                     8
# 1  01/04/2010   5:00        12.2            10.1                   7.9
# 2  01/04/2010   8:00        16.5            12.9                   9.4
# 3  01/04/2010  11:00        19.7            15.4                  11.9
# 4  01/04/2010  14:00        20.9            16.1                  12.3
#
#   Relative humidity wind speed Wind Direction (Degrees)
# 0                69        2.5                      110
# 1                75          3                      110
# 2                63          1                      320
# 3                61        3.5                      240
# 4                58          3                      310

# %% [markdown]
# ### Adding a Column to Describe if it's Day or Night (AM/PM)

# %%
# removing the ':00' prefix from the Hour 
df['Hour'] = df['Hour'].str[:-3].astype(int)

# %%
# adding a AM/PM column to distinguish between day and night temps
df['AMPM'] = np.where(df['Hour'] < 12, 'am', 'pm')

# %%
df.head()
# Out:
#          Date  Hour Temperature Wet Temperature Dew point Temperature  \
# 0  01/04/2010     2        13.6            10.8                     8
# 1  01/04/2010     5        12.2            10.1                   7.9
# 2  01/04/2010     8        16.5            12.9                   9.4
# 3  01/04/2010    11        19.7            15.4                  11.9
# 4  01/04/2010    14        20.9            16.1                  12.3
#
#   Relative humidity wind speed Wind Direction (Degrees) AMPM
# 0                69        2.5                      110   am
# 1                75          3                      110   am
# 2                63          1                      320   am
# 3                61        3.5                      240   am
# 4                58          3                      310   pm

# %%
df.columns
# Out:
# Index(['Date', 'Hour', 'Temperature', 'Wet Temperature',
#        'Dew point Temperature', 'Relative humidity', 'wind speed',
#        'Wind Direction (Degrees)', 'AMPM'],
#       dtype='object')

# %% [markdown]
# ### Separate into Categorical and Contineous Variables

# %%
cont_col = ['Wet Temperature','Dew point Temperature','Relative humidity','wind speed','Wind Direction (Degrees)']
cat_col = ['Hour','AMPM']
label_col = ['Temperature']

# %%
# removing all rows have missing values to avoid misleading data
print(len(df))
for col in cont_col:
    df = df[~df[col].str.contains('-')]
print(len(df))
# Out:
# 28714
# 27455

# %%
# for cat in cat_col:
#     df[cat] = df[cat].astype('category')

df = SelfAI.define_type(df, cat_col, 'category')
df = SelfAI.define_type(df, cont_col, 'float')
df[label_col] = df[label_col].astype(float)

# %% [markdown]
# ### Calculating the mean temperature for each hour of the day to fill the missing temperature columns

# %%
meanTemp = df.groupby('Hour').agg({'Temperature' : np.mean})
meanTemp
# Out:
#       Temperature
# Hour
# 2       20.412880
# 5       19.412868
# 8       21.412547
# 11      23.420712
# 14      23.838802
# 17      23.103401
# 20      22.167461
# 23      21.392418

# %%
# df['Temperature'] = df['Temperature'].replace(0,meanTemp)
for ind in df.index: 
    if df['Temperature'][ind] == 0:
        df['Temperature'][ind] = (meanTemp['Temperature'][df['Hour'][ind]])

# %% [markdown]
# ### Stacking categorical, contineous and labels and turning them into tensors

# %%
df.dtypes
# Out:
# Date                          object
# Hour                        category
# Temperature                  float64
# Wet Temperature              float64
# Dew point Temperature        float64
# Relative humidity            float64
# wind speed                   float64
# Wind Direction (Degrees)     float64
# AMPM                        category
# dtype: object

# %%
cat_stack = SelfAI.stack_cols(df, cat_col, torch.int64, cat=1)
cont_stack = SelfAI.stack_cols(df, cont_col, torch.float)
labels = SelfAI.stack_cols(df, label_col, torch.float)

# %%
# torch.tensor(df[label_col].values, dtype=torch.float).reshape(-1,1)

# %%
cat_stack.shape
# Out:
# torch.Size([27455, 2])

# %%
cont_stack.shape
# Out:
# torch.Size([27455, 5])

# %%
labels.shape
# Out:
# torch.Size([27455, 1])

# %% [markdown]
# ### Creating embedding sizes list

# %%
cat_szs = [len(df[col].cat.categories) for col in cat_col]
emb_szs = [(size, min(50, (size+1)//2)) for size in cat_szs]
emb_szs
# Out:
# [(8, 4), (2, 1)]

# %% [markdown]
# ### Creating a Tabular Model

# %%
class TabularWeatherModel(nn.Module):
    
    def __init__(self, emb_szs, num_cont, out_size, layers, p=0.5):
        super().__init__()
        self.embeds = nn.ModuleList([nn.Embedding(ni,nf) for ni,nf in emb_szs])
        self.embeds_drop = nn.Dropout(p)
        
        self.bn_cont = nn.BatchNorm1d(num_cont)

        layerlist = []
        n_emb = sum((nf for ni,nf in emb_szs))
        num_input = n_emb + num_cont
        
        for i in layers:
            layerlist.append(nn.Linear(num_input,i)) 
            layerlist.append(nn.ReLU(inplace=True))
            num_input = i
        layerlist.append(nn.Linear(layers[-1], out_size))
        
        self.layers = nn.Sequential(*layerlist)
        
    def forward(self, x_cat, x_cont):
        embeddings = []
        for i,e in enumerate(self.embeds):
            embeddings.append(e(x_cat[:,i]))
            x = torch.cat(embeddings, 1)
            x = self.embeds_drop(x)
            
        x = self.bn_cont(x_cont)
        x = torch.cat([x,x_cont],1)
        x = self.layers(x)
        
        return x

# %%
WeatherModel = TabularWeatherModel(emb_szs, cont_stack.shape[1], 1, [200,100], p=0.4)

# %%
WeatherModel
# Out:
# TabularWeatherModel(
#   (embeds): ModuleList(
#     (0): Embedding(8, 4)
#     (1): Embedding(2, 1)
#   )
#   (embeds_drop): Dropout(p=0.4)
#   (bn_cont): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=10, out_features=200, bias=True)
#     (1): ReLU(inplace)
#     (2): Linear(in_features=200, out_features=100, bias=True)
#     (3): ReLU(inplace)
#     (4): Linear(in_features=100, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ### Define loss function and optimizer

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(WeatherModel.parameters(), lr=0.001)

# %%
bs = 6000
test_size = int(bs * 0.2)

conts_train = cont_stack[:bs-test_size]
conts_test = cont_stack[bs-test_size:bs]
cats_train = cat_stack[:bs-test_size]
cats_test = cat_stack[bs-test_size:bs]
labels_train = labels[:bs-test_size]
labels_test = labels[bs-test_size:bs]

# %%
len(conts_train)
# Out:
# 4800

# %%
labels_test
# Out:
# tensor([[12.7000],
#         [12.8000],
#         [11.6000],
#         ...,
#         [26.4000],
#         [26.1000],
#         [25.6000]])

# %%
len(cats_train)
# Out:
# 4800

# %% [markdown]
# ### Train the model on the given data and print&plot results

# %%
import time 
start_time = time.time()

epochs = 1000
losses = []

for i in range(epochs):
    i+=1
    
    labels_pred = WeatherModel(cats_train, conts_train)
    loss = criterion(labels_pred, labels_train)
    
    losses.append(loss)
    
    if i%100 == 1:
        print(f'epoch: {i:3}  loss: {loss.item():10.8f}')
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
print(f'epoch: {i:3}  loss: {loss.item():10.8f}') 
print(f'\nTraining Time: {(time.time() - start_time )/60}')
# Out:
# epoch:   1  loss: 662.62249756
# epoch: 101  loss: 4.31621361
# epoch: 201  loss: 0.10575122
# epoch: 301  loss: 0.05116569
# epoch: 401  loss: 0.03923140
# epoch: 501  loss: 0.03285478
# epoch: 601  loss: 0.02891129
# epoch: 701  loss: 0.02736052
# epoch: 801  loss: 0.02985821
# epoch: 901  loss: 0.09047576
# epoch: 1000  loss: 0.02827377
#
# Training Time: 0.43560107549031574

# %%
plt.plot(range(epochs), losses)
plt.ylabel('MSE Loss')
plt.xlabel('epoch');

# %% [markdown]
# ### Evaluate the model on the test set

# %%
with torch.no_grad():
    labels_val = WeatherModel(cats_test, conts_test)
    loss = criterion(labels_test, labels_val)
print(loss)
# Out:
# tensor(0.5165)

# %%
diffList = []
print(f'{"PREDICTED":>12} {"ACTUAL":>8} {"DIFF":>8}')
for i in range(1200):
    diff = np.abs(labels_val[i].item()-labels_test[i].item())
    diffList.append(diff)
    print(f'{i+1:2}. {labels_val[i].item():8.4f} {labels_test[i].item():8.4f} {diff:8.4f}')
# Out:
#    PREDICTED   ACTUAL     DIFF
#  1.  11.9186  12.7000   0.7814
#  2.  12.0716  12.8000   0.7284
#  3.  10.8892  11.6000   0.7108
#  4.  15.7090  16.3000   0.5910
#  5.  18.1776  18.6000   0.4224
#  6.  15.4451  16.0000   0.5549
#  7.  12.2512  12.7000   0.4488
#  8.  10.3522  11.0000   0.6478
#  9.   9.7260  10.2000   0.4740
# 10.   9.2273   9.6000   0.3727
# 11.  10.3379  10.7000   0.3621
# 12.  16.9840  17.7000   0.7160
# 13.  19.3528  20.2000   0.8472
# 14.  15.8654  16.6000   0.7346
# 15.  14.9198  15.7000   0.7802
# 16.  10.8741  11.5000   0.6259
# 17.  11.0335  11.5000   0.4665
# 18.  12.7118  13.0000   0.2882
# 19.  12.9209  13.3000   0.3791
# 20.  15.8686  16.3000   0.4314
# 21.  16.7097  17.2000   0.4903
# 22.  15.9039  16.3000   0.3961
# 23.  14.8369  15.3000   0.4631
# 24.  13.5572  13.9000   0.3428
# 25.  12.4923  12.7000   0.2077
# 26.  11.4333  11.8000   0.3667
# 27.  11.9233  12.2000   0.2767
# 28.  15.5487  16.1000   0.5513
# 29.  17.5073  18.2000   0.6927
# 30.  15.6126  16.3000   0.6874
# 31.  13.5710  14.2000   0.6290
# 32.  11.5223  12.1000   0.5777
# 33.  10.9257  11.4000   0.4743
# 34.   9.8256  10.1000   0.2744
# 35.  11.4206  11.8000   0.3794
# 36.  17.2522  17.6000   0.3478
# 37.  18.4957  19.2000   0.7043
# 38.  15.7898  16.3000   0.5102
# 39.  14.0159  14.8000   0.7841
# 40.  10.5677  11.2000   0.6323
# 41.  10.2120  10.7000   0.4880
# 42.  12.0860  12.4000   0.3140
# 43.  11.9151  12.1000   0.1849
# 44.  14.1244  14.4000   0.2756
# 45.  12.3326  12.9000   0.5674
# 46.  13.6595  13.8000   0.1405
# 47.  13.7046  14.1000   0.3954
# 48.  11.4439  12.1000   0.6561
# 49.  10.2193  10.9000   0.6807
# 50.   9.7972  10.2000   0.4028
# 672.  16.5644  17.4000   0.8356
# 673.  17.3807  17.9000   0.5193
# 674.  18.2620  18.8000   0.5380
# 675.  18.9639  19.7000   0.7361
# 676.  18.8867  19.4000   0.5133
# 677.  17.9163  18.6000   0.6837
# 678.  17.2059  18.0000   0.7941
# 679.  16.5656  17.5000   0.9344
# 680.  16.0135  16.8000   0.7865
# 681.  13.5810  14.3000   0.7190
# 682.  16.8313  17.7000   0.8687
# 683.  18.1110  18.8000   0.6890
# 684.  18.7639  19.3000   0.5361
# 685.  17.8208  18.3000   0.4792
# 686.  17.1066  17.9000   0.7934
# 687.  16.7355  17.9000   1.1645
# 688.  16.8021  17.6000   0.7979
# 689.  15.7175  16.5000   0.7825
# 690.  18.4326  19.2000   0.7674
# 691.  19.0251  19.8000   0.7749
# 692.  18.7187  19.3000   0.5813
# 693.  18.0406  18.8000   0.7594
# 694.  17.4785  18.1000   0.6215
# 695.  16.4972  17.5000   1.0028
# 696.  14.6193  15.3000   0.6807
# 697.  13.0934  13.7000   0.6066
# 698.  17.2886  18.2000   0.9114
# 699.  19.0413  19.8000   0.7587
# 700.  20.0349  20.7000   0.6651
# 701.  19.6452  20.2000   0.5548
# 702.  18.8530  19.9000   1.0470
# 703.  17.7352  18.8000   1.0648
# 704.  17.4769  18.2000   0.7231
# 705.  14.0353  14.8000   0.7647
# 706.  18.4464  19.3000   0.8536
# 707.  19.3686  20.3000   0.9314
# 708.  19.4252  20.1000   0.6748
# 709.  18.5664  19.2000   0.6336
# 710.  17.5410  18.3000   0.7590
# 711.  17.2365  18.0000   0.7635
# 712.  16.2547  17.2000   0.9453
# 713.  14.9503  15.7000   0.7497
# 714.  17.8582  18.8000   0.9418
# 715.  19.2519  20.0000   0.7481
# 716.  18.8958  19.5000   0.6042
# 717.  18.4893  19.0000   0.5107
# 718.  18.2584  18.9000   0.6416
# 719.  18.0177  18.8000   0.7823
# 720.  17.7381  18.5000   0.7619
# 721.  16.5342  17.5000   0.9658
# 722.  18.4529  19.4000   0.9471
# 723.  19.3943  20.1000   0.7057
# 724.  19.1693  19.9000   0.7307
# 725.  19.2077  19.8000   0.5923
# 726.  18.7413  19.5000   0.7587
# 727.  18.2346  19.1000   0.8654
# 728.  17.0029  17.9000   0.8971
# 729.  15.3111  16.0000   0.6889
# 730.  16.8352  17.7000   0.8648
# 731.  19.2034  20.0000   0.7966
# 732.  20.3659  21.2000   0.8341
# 733.  19.7685  20.6000   0.8315
# 734.  18.4714  19.4000   0.9286
# 735.  18.0356  18.9000   0.8644
# 736.  16.1584  16.8000   0.6416
# 737.  15.7512  16.5000   0.7488
# 738.  17.2662  18.2000   0.9338
# 739.  19.2413  20.0000   0.7587
# 740.  20.6184  21.4000   0.7816
# 741.  19.9485  20.7000   0.7515
# 742.  18.9955  19.8000   0.8045
# 743.  18.1178  19.1000   0.9822
# 744.  15.9547  16.9000   0.9453
# 745.  14.3479  15.0000   0.6521
# 746.  18.3826  19.4000   1.0174
# 747.  19.5254  20.3000   0.7746
# 748.  19.1110  19.6000   0.4890
# 749.  19.1584  19.6000   0.4416
# 750.  18.9870  19.6000   0.6130
# 751.  18.7006  19.6000   0.8994
# 752.  17.9738  18.8000   0.8262
# 753.  17.4708  18.4000   0.9292
# 754.  18.6151  19.4000   0.7849
# 755.  19.2258  19.9000   0.6742
# 756.  19.1964  19.8000   0.6036
# 757.  19.0754  20.0000   0.9246
# 758.  19.0230  19.9000   0.8770
# 759.  18.3752  19.2000   0.8248
# 760.  16.5310  17.5000   0.9690
# 761.  17.1837  18.1000   0.9163
# 762.  19.2670  20.1000   0.8330
# 763.  20.0812  20.9000   0.8188
# 764.  20.3370  21.0000   0.6630
# 765.  20.1715  20.6000   0.4285
# 766.  19.0258  19.8000   0.7742
# 767.  19.0394  19.9000   0.8606
# 768.  19.0395  19.7000   0.6605
# 769.  19.2291  19.9000   0.6709
# 770.  21.3718  22.3000   0.9282
# 771.  24.6185  25.3000   0.6815
# 772.  22.8393  23.7000   0.8607
# 773.  21.7032  22.3000   0.5968
# 774.  20.2301  20.8000   0.5699
# 775.  19.9177  20.7000   0.7823
# 776.  19.0851  20.0000   0.9149
# 777.  19.4645  20.3000   0.8355
# 778.  20.4977  21.2000   0.7023
# 779.  21.2115  21.8000   0.5885
# 780.  21.8676  22.7000   0.8324
# 781.  20.0180  20.8000   0.7820
# 782.  20.2411  21.2000   0.9589
# 783.  19.1293  19.9000   0.7707
# 784.  18.8530  19.9000   1.0470
# 785.  18.5861  19.5000   0.9139
# 786.  20.9700  21.9000   0.9300
# 787.  21.1720  21.9000   0.7280
# 788.  21.2861  21.9000   0.6138
# 789.  20.5346  21.3000   0.7654
# 790.  19.7005  20.5000   0.7995
# 791.  19.4060  20.3000   0.8940
# 792.  18.5526  19.5000   0.9474
# 793.  16.5978  17.5000   0.9022
# 794.  20.9384  21.9000   0.9616
# 795.  22.3556  23.3000   0.9444
# 796.  22.8529  23.8000   0.9471
# 797.  22.0247  22.7000   0.6753
# 798.  20.4978  21.3000   0.8022
# 799.  19.5798  20.4000   0.8202
# 800.  17.6939  18.8000   1.1061
# 801.  15.9159  16.6000   0.6841
# 802.  23.3052  24.6000   1.2948
# 803.  22.3481  23.3000   0.9519
# 804.  22.3742  23.3000   0.9258
# 805.  21.9551  22.6000   0.6449
# 806.  22.5847  23.3000   0.7153
# 807.  22.3018  23.3000   0.9982
# 808.  19.6456  20.6000   0.9544
# 809.  19.2037  20.1000   0.8963
# 810.  21.7502  22.8000   1.0498
# 811.  22.9014  23.9000   0.9986
# 812.  21.5319  22.1000   0.5681
# 813.  21.2759  21.9000   0.6241
# 814.  20.3902  21.2000   0.8098
# 815.  19.0582  19.8000   0.7418
# 816.  18.0973  18.8000   0.7027
# 817.  16.8595  17.6000   0.7405
# 818.  19.4005  20.5000   1.0995
# 819.  20.7330  21.4000   0.6670
# 820.  21.3670  22.1000   0.7330
# 821.  20.0685  20.6000   0.5315
# 822.  19.3391  20.0000   0.6609
# 823.  18.6819  19.4000   0.7181
# 824.  18.3389  19.1000   0.7611
# 825.  16.6538  17.5000   0.8462
# 826.  19.8552  20.8000   0.9448
